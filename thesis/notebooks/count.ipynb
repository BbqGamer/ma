# %%
import pandas as pd

# %%
iee = pd.read_csv("../exports/export2025.12.10-17.08.03.csv")
scholar = pd.read_csv("../exports/google-scholar.csv", sep=";")
scopus = pd.read_csv("../exports/scopus_export_Dec_10-2025_1ba3c940-0bdc-494a-bee4-d98e57b428f5.csv")
snowball = pd.read_csv('../exports/snowballing.csv')

# %%
iee
# Out:
#                                        Document Title  \
# 0   A Simple Approach to Balance Task Loss in Mult...
# 1   Early Lane Change Prediction for Automated Dri...
# 2   Comparison of Loss Function Weighting Methods ...
# 3   Curriculum-Based Asymmetric Multi-Task Reinfor...
# 4   Adaptive Data and Task Joint Scheduling for Mu...
# 5   Hierarchical Curriculum Learning for Dysarthri...
# 6   Revisiting Fairness in Multitask Learning: A P...
# 7   Calculation of Optimized Pulse Patterns for El...
# 8   Adaptive Weighting Based Metal Artifact Reduct...
# 9   Wireless Capsule Endoscopy Diagnosis Using Pro...
# 10  Multi-Task Convolutional Neural Network for Po...
# 11  Multi-objective Memetic Algorithm with Adaptiv...
# 12  Joint Modeling for ASR Correction and Dialog S...
# 13  Data vs. Physics: The Apparent Pareto Front of...
# 14  DAO to HANOI via DeSci: AI Paradigm Shifts fro...
# 15  Acoustic Prompt Tuning: Empowering Large Langu...
# ...

# %%
scholar
# Out:
#                                                 Title
# 0   MTL-BERT: A Multi-Task Learning Framework for ...
# 1   SPC: Selective Patches Consistency for Cross-D...
# 2   Socialized Coevolution: Advancing a Better Wor...
# 3   Task-adaptive debiasing with SCM for sentiment...
# 4   M2-reasoning: Empowering mllms with unified ge...
# ..                                                ...
# 68  Beyond Tokens: Introducing Large Semiosis Mode...
# 69  Knowledge distillation meets open-set semi-sup...
# 70                              Procedural Strategies
# 71  Reinforcement Learning for Autonomous Mobility...
# 72  Platform for orchestrating a scalable, privacy...
#
# [73 rows x 1 columns]

# %%
jscopus
# Out:
#                                               Authors  \
# 0                 Guo, Y.; Ai, X.; Guo, M.; Cheng, S.
# 1   Atamni, N.; Madi, B.; Bordman, S.; Vasyutinsky...
# 2   Dagnaw, G.H.; Zhu, Y.; Maqsood, M.H.; Yin, X.;...
# 3   Yuan, L.; Zhou, H.-B.; Li, J.-Y.; Liu, L.; Gu,...
# 4                               Kadlec, P.; Čapek, M.
# 5          Zou, M.; Yu, B.; Zhan, Y.; Lyu, S.; Ma, K.
# 6             Setiyadi, Y.; Santoso, J.; Surendro, K.
# 7             Wang, D.; Zhang, T.; Yuan, C.; Wang, X.
# 8   Rohrhofer, F.M.; Posch, S.; Gobnitzer, C.; Gei...
# 9   Mozaffari, S.; Arnold, E.; Dianati, M.; Fallah...
# 10    Hervella, Á.S.; Rouco, J.; Novo, J.; Ortega, M.
# 11             de Lhoneux, M.; Zhang, S.; Sogaard, A.
# 12  Chennupati, S.; Sistu, G.; Yogamani, S.; Rawas...
# 13                                   Yin, X.; Liu, X.
# 14                            Hassani, K.; Lee, W.-S.
# 15    Izui, K.; Yamada, T.; Nishiwaki, S.; Tanaka, K.
# ...

# %%
titles = pd.concat([scopus["Source title"], iee["Document Title"], scholar["Title"], snowball["Title"]], ignore_index=True)

# %%
titles.sort_values()
# Out:
# 17     A Simple Approach to Balance Task Loss in Mult...
# 110    A Survey of Multi-task Learning in Natural Lan...
# 57     A Systematic Literature Review on Multimodal A...
# 47     A lightweight operation mode decision method f...
# 80            A survey of direct preference optimization
#                              ...
# 126    Visualizing and Understanding Curriculum Learn...
# 86     When Remote Sensing Meets Foundation Model: A ...
# 26     Wireless Capsule Endoscopy Diagnosis Using Pro...
# 6                                                    NaN
# 12                                                   NaN
# Length: 127, dtype: object

# %%
cieee = iee[iee["Chosen"]]
cieee
# Out:
#                                        Document Title  \
# 3   Curriculum-Based Asymmetric Multi-Task Reinfor...
# 5   Hierarchical Curriculum Learning for Dysarthri...
# 9   Wireless Capsule Endoscopy Diagnosis Using Pro...
# 17  Closed-Loop Control of Droplet Quality Based o...
#
#                                               Authors  \
# 3                    H. Huang; D. Ye; L. Shen; W. Liu
# 5                             I. -T. Hsieh; C. -H. Wu
# 9               X. Li; Q. Wu; Y. Chen; K. Wu; L. Meng
# 17  Y. Shen; H. Zhan; Y. Zhang; Y. Zhang; S. Tang;...
#
#                                   Author Affiliations  \
# 3   Nanyang Technological University, Singapore; T...
# 5   Graduate Program of Multimedia Systems and Int...
# 9   School of Management, Huazhong University of S...
# 17  College of Mechanical Engineering, Zhejiang Un...
#
#                                     Publication Title Date Added To Xplore  \
# ...

# %%
cscopus = scopus[scopus["Chosen"]]
cscopus
# Out:
#                                               Authors  \
# 7             Wang, D.; Zhang, T.; Yuan, C.; Wang, X.
# 9   Mozaffari, S.; Arnold, E.; Dianati, M.; Fallah...
# 11             de Lhoneux, M.; Zhang, S.; Sogaard, A.
#
#                                     Author full names  \
# 7   Wang, Deyuan (58706241200); Zhang, Tiantian (5...
# 9   Mozaffari, Sajjad (57219585131); Arnold, Eduar...
# 11  de Lhoneux, Miryam (57193355196); Zhang, Sheng...
#
#                                          Author(s) ID  \
# 7   58706241200; 58738159200; 37056632700; 3523564...
# 9   57219585131; 57211023741; 8930535800; 57212012224
# 11              57193355196; 57211157782; 24336006300
#
#                                                 Title  Year  \
# 7   Joint Modeling for ASR Correction and Dialog S...  2023
# 9   Early Lane Change Prediction for Automated Dri...  2022
# 11  Zero-Shot Dependency Parsing with Worst-Case A...  2022
#
# ...

# %%
cscholar = scholar[scholar["Chosen"]]
cscholar
# Out:
#                                                 Title  Chosen
# 0   MTL-BERT: A Multi-Task Learning Framework for ...    True
# 1   SPC: Selective Patches Consistency for Cross-D...    True
# 5   REST: Drug-drug interaction prediction via rei...    True
# 6   Open-ended coordination for multi-agent system...    True
# 9   Beyond Standard Losses: Redefining Text-to-SQL...    True
# 10  A lightweight operation mode decision method f...    True
# 13  Shy-hunyuan-MT at WMT25 General Machine Transl...    True
# 14  Backpropagation-based Parameter Tuning and Gra...    True
# 15  LocalGCL: Local-aware Contrastive Learning for...    True
# 16  Adaptive training distributions with scalable ...    True
# 17  Vision Large Language Models Are Good Noise Ha...    True
# 18  Uncertainty-aware evidential fusion-based lear...    True
# 19  A weighted difference loss approach for enhanc...    True
# 22                              Modular deep learning    True
# ...

# %%
ctitles = pd.concat([cscopus["Source title"], cieee["Document Title"], cscholar["Title"], snowball["Title"]], ignore_index=True)
ctitles.sort_values()
# Out:
# 39    A Survey of Multi-task Learning in Natural Lan...
# 12    A lightweight operation mode decision method f...
# 29           A survey of direct preference optimization
# 19    A weighted difference loss approach for enhanc...
# 16    Adaptive training distributions with scalable ...
# 35    Applied Deep Learning for Natural Language Pro...
# 14    Backpropagation-based Parameter Tuning and Gra...
# 11    Beyond Standard Losses: Redefining Text-to-SQL...
# 6     Closed-Loop Control of Droplet Quality Based o...
# 40    Competence-based Curriculum Learning for Neura...
# 41    Curriculum Learning via Transitional Objective...
# 42                        Curriculum Learning: A Survey
# 43                                  Curriculum learning
# 3     Curriculum-Based Asymmetric Multi-Task Reinfor...
# 25    Detecting Data Deviations in Electronic Health...
# 44    Efficient Knowledge Distillation via Curriculu...
# 24    Feature Based Methods in Domain Adaptation for...
# ...
